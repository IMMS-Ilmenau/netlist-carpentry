# %% [markdown]
# # Accessing Circuit Data with Netlist Carpentry
# This notebook demonstrates how to access the data of a circuit using Netlist Carpentry, based on a very simple circuit design.
#
# ## Read from the Verilog file
# - First read the verilog file and transform into a [Circuit Object](../src/netlist_carpentry/core/circuit.py).
# - Modules can be created and added to the circuit via the `Circuit.create_module` method.
# - Modules can also be removed from the circuit via the `Circuit.remove_module` method.
# - Both methods return True or False depending on whether the operation was successful or not.
# - Top module of the circuit can be accessed and changed via `Circuit.set_top`.

# %%
import netlist_carpentry
from netlist_carpentry.core.exceptions import ObjectNotFoundError

circuit = netlist_carpentry.read("files/simpleAdder.v")
print(f"The circuit currently has {len(circuit.modules)} module: {', '.join(circuit.modules.keys())}")

circuit.create_module("new_empty_module")
print(f"The circuit now has {len(circuit.modules)} modules: {', '.join(circuit.modules.keys())}")

print(f"The top module of the circuit is currently '{circuit.top_name}'.")
circuit.set_top("new_empty_module")
print(f"Now, it's '{circuit.top_name}'.")

circuit.remove_module("new_empty_module")
print(f"The circuit again has {len(circuit.modules)} module: {', '.join(circuit.modules.keys())}")

print(f"The top module of the circuit is now '{circuit.top_name}', since the module specified as top module no longer exists!")
try:
    print(f"The object returned by circuit.top is thus {circuit.top}!")
except ObjectNotFoundError as e:
    print(f"Catched an ObjectNotFoundError: {e}")
circuit.set_top("simpleAdder")
print(f"Now, the top module is '{circuit.top_name}' again.")
# Out:
# Net preprocessing progress: 100%|██████████| 8/8 [00:00<00:00, 32171.08it/s]
# Wire building progress: 100%|██████████| 8/8 [00:00<00:00, 2315.86it/s]
# Port building progress: 100%|██████████| 6/6 [00:00<00:00, 1488.05it/s]
# Instance building progress: 100%|██████████| 4/4 [00:00<00:00, 123.77it/s]
# The circuit currently has 1 module: simpleAdder
# The circuit now has 2 modules: simpleAdder, new_empty_module
# The top module of the circuit is currently ''.
# Now, it's 'new_empty_module'.
# WARNING:   Removing top module 'new_empty_module'! Set a new top module using Circuit.set_top(), otherwise hierarchy cannot be determined!
# The circuit again has 1 module: simpleAdder
# The top module of the circuit is now '', since the module specified as top module no longer exists!
# Catched an ObjectNotFoundError: No top module found! Name of top module is currently set to ''!
# Now, the top module is 'simpleAdder' again.

# %% [markdown]
# ## Collect names of instances, ports and wires
# - Retrieve the top module via `Circuit.top_module`.
# - The content of a module can be directly accessed via `Module.instances`, `Module.ports` or `Module.wires`, which are dictionaries of the form `Dict[str, Instance]`, `Dict[str, Port]` and `Dict[str, Wire]` respectively.
# - To retrieve key-value pairs of each of these dictionaries, you can use `Module.instances.items()`, `Module.ports.items()` or `Module.wires.items()` and iterate over them.
# - The keys of each dictionary are the names of each instance, port or wire.
# - The values of each dictionary are the corresponding instance, port or wire objects.

# %%
top_module = circuit.top

print(f"The top module '{top_module.name}' has the following instances:")
for instance_name, instance_object in top_module.instances.items():
    print(f"\tInstance '{instance_name}' of type '{instance_object.instance_type}' (Class name: {instance_object.__class__.__name__}).")

print(f"The top module '{top_module.name}' has the following ports:")
for port_name, port_object in top_module.ports.items():
    print(f"\tPort '{port_name}', which is an {port_object.direction} port and {port_object.width} bit wide!")

print(f"The top module '{top_module.name}' has the following wires:")
for wire_name, wire_object in top_module.wires.items():
    print(f"\tWire '{wire_name}', which is {wire_object.width} bit wide!")
# Out:
# The top module 'simpleAdder' has the following instances:
# 	Instance '§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2' of type '§add' (Class name: Adder).
# 	Instance '§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3' of type '§or' (Class name: OrGate).
# 	Instance '§procdff§6' of type '§adff' (Class name: ADFF).
# 	Instance '§procdff§9' of type '§adff' (Class name: ADFF).
# The top module 'simpleAdder' has the following ports:
# 	Port 'clk', which is an input port and 1 bit wide!
# 	Port 'rst', which is an input port and 1 bit wide!
# 	Port 'in1', which is an input port and 8 bit wide!
# 	Port 'in2', which is an input port and 8 bit wide!
# 	Port 'out', which is an output port and 9 bit wide!
# 	Port 'out2', which is an output port and 8 bit wide!
# The top module 'simpleAdder' has the following wires:
# 	Wire '§0§out2§7§0§', which is 8 bit wide!
# 	Wire '§0§out§8§0§', which is 9 bit wide!
# 	Wire 'clk', which is 1 bit wide!
# 	Wire 'in1', which is 8 bit wide!
# 	Wire 'in2', which is 8 bit wide!
# 	Wire 'out', which is 9 bit wide!
# 	Wire 'out2', which is 8 bit wide!
# 	Wire 'rst', which is 1 bit wide!

# %% [markdown]
# ## Analyze the contents of a module
# - Ports define the interface of the module, e.g. what inputs it takes and what outputs it produces.
# - Wires represent signals that are passed between module ports and instances of the module.
# - Instances define how the module processes signals, and how signals are combined to create new signals.
# - In the cell below, some attributes and methods related to ports are presented.

# %%
clock_port = top_module.get_port("clk")
print(f"The port '{clock_port.name}' is a {clock_port.direction} port.")

if clock_port.is_driver: # Clock Port is a signal driving port
    print(f"The port '{clock_port.name}' is also a signal driving port.")
else:
    print(f"The port '{clock_port.name}' is not a signal driving port.")

if clock_port.is_load: # Clock Port is NOT a signal receiving port
    print(f"The port '{clock_port.name}' is also a signal receiving port.")
else:
    print(f"The port '{clock_port.name}' is not a signal receiving port.")

print(f"The port '{clock_port.name}' has {len(clock_port.connected_wires)} wire(s) connected to it.")
print(f"The full paths of the connected wires are: {', '.join([wire.raw for wire in clock_port.connected_wires])}")
print("The paths follow the format <module_name>.<wire_name>.<wire_index>")
# Out:
# The port 'clk' is a input port.
# The port 'clk' is also a signal driving port.
# The port 'clk' is not a signal receiving port.
# The port 'clk' has 1 wire(s) connected to it.
# The full paths of the connected wires are: simpleAdder.clk
# The paths follow the format <module_name>.<wire_name>.<wire_index>

# %% [markdown]
# - In the cell below, some methods related to instances are shown.
# - Instances of primitive gates often have seemingly cryptic names generated by Yosys (e.g. `$add$simpleAdder.v:26$2`), which are internally simplified.
# - Any special characters in the name are replaced with paragraph symbols (`§`).
# - Instances can be selected in many different ways -- in the cell below, all instances of a certain type (Adder) are selected.
# - Selecting an instance from the list of Adder instances allows to access its properties, such as its ports.

# %%
print(f"The module {top_module.name} contains instances with the names: {', '.join(top_module.instances.keys())}")
print(f"Instances can also be sorted by instance type: {top_module.instances_by_types}")
print("All instances of a certain type can be selected via 'Module.instances_by_types[instance_type]'.")

adder_instances = top_module.instances_by_types["§add"]


print(f"The module contains {len(adder_instances)} adders: {adder_instances}")

for adder_inst in adder_instances:
    print(f"The first adder instance has the name {adder_inst.name} and {len(adder_inst.ports)} ports:")
    for port_name, port_object in adder_inst.ports.items():
        print(f"\tPort {port_name} is {port_object.width} bit wide and thus contains {len(port_object.segments)} segments.")
        # Alternative representation: 'for seg_idx, segment in port_object.segments.items()'
        for seg_idx, segment in port_object: # Segments are used to represent multi-bit signals
            print(f"\t\tPort Segment {seg_idx} is connected to wire segment {segment.raw_ws_path}. Alternative representation: index {segment.ws_path.name} of wire {segment.ws_path.parent.name}")
# Out:
# The module simpleAdder contains instances with the names: §add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2, §or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3, §procdff§6, §procdff§9
# Instances can also be sorted by instance type: {'§add': [Adder(§add: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2)], '§or': [OrGate(§or: simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3)], '§adff': [ADFF(§adff: simpleAdder.§procdff§6), ADFF(§adff: simpleAdder.§procdff§9)]}
# All instances of a certain type can be selected via 'Module.instances_by_types[instance_type]'.
# The module contains 1 adders: [Adder(§add: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2)]
# The first adder instance has the name §add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2 and 3 ports:
# 	Port A is 8 bit wide and thus contains 8 segments.
# 		Port Segment 0 is connected to wire segment simpleAdder.in1.0. Alternative representation: index 0 of wire in1
# 		Port Segment 1 is connected to wire segment simpleAdder.in1.1. Alternative representation: index 1 of wire in1
# 		Port Segment 2 is connected to wire segment simpleAdder.in1.2. Alternative representation: index 2 of wire in1
# 		Port Segment 3 is connected to wire segment simpleAdder.in1.3. Alternative representation: index 3 of wire in1
# 		Port Segment 4 is connected to wire segment simpleAdder.in1.4. Alternative representation: index 4 of wire in1
# 		Port Segment 5 is connected to wire segment simpleAdder.in1.5. Alternative representation: index 5 of wire in1
# 		Port Segment 6 is connected to wire segment simpleAdder.in1.6. Alternative representation: index 6 of wire in1
# 		Port Segment 7 is connected to wire segment simpleAdder.in1.7. Alternative representation: index 7 of wire in1
# 	Port B is 8 bit wide and thus contains 8 segments.
# 		Port Segment 0 is connected to wire segment simpleAdder.in2.0. Alternative representation: index 0 of wire in2
# 		Port Segment 1 is connected to wire segment simpleAdder.in2.1. Alternative representation: index 1 of wire in2
# 		Port Segment 2 is connected to wire segment simpleAdder.in2.2. Alternative representation: index 2 of wire in2
# 		Port Segment 3 is connected to wire segment simpleAdder.in2.3. Alternative representation: index 3 of wire in2
# 		Port Segment 4 is connected to wire segment simpleAdder.in2.4. Alternative representation: index 4 of wire in2
# 		Port Segment 5 is connected to wire segment simpleAdder.in2.5. Alternative representation: index 5 of wire in2
# 		Port Segment 6 is connected to wire segment simpleAdder.in2.6. Alternative representation: index 6 of wire in2
# 		Port Segment 7 is connected to wire segment simpleAdder.in2.7. Alternative representation: index 7 of wire in2
# 	Port Y is 9 bit wide and thus contains 9 segments.
# 		Port Segment 0 is connected to wire segment simpleAdder.§0§out§8§0§.0. Alternative representation: index 0 of wire §0§out§8§0§
# 		Port Segment 1 is connected to wire segment simpleAdder.§0§out§8§0§.1. Alternative representation: index 1 of wire §0§out§8§0§
# 		Port Segment 2 is connected to wire segment simpleAdder.§0§out§8§0§.2. Alternative representation: index 2 of wire §0§out§8§0§
# 		Port Segment 3 is connected to wire segment simpleAdder.§0§out§8§0§.3. Alternative representation: index 3 of wire §0§out§8§0§
# 		Port Segment 4 is connected to wire segment simpleAdder.§0§out§8§0§.4. Alternative representation: index 4 of wire §0§out§8§0§
# 		Port Segment 5 is connected to wire segment simpleAdder.§0§out§8§0§.5. Alternative representation: index 5 of wire §0§out§8§0§
# 		Port Segment 6 is connected to wire segment simpleAdder.§0§out§8§0§.6. Alternative representation: index 6 of wire §0§out§8§0§
# 		Port Segment 7 is connected to wire segment simpleAdder.§0§out§8§0§.7. Alternative representation: index 7 of wire §0§out§8§0§
# 		Port Segment 8 is connected to wire segment simpleAdder.§0§out§8§0§.8. Alternative representation: index 8 of wire §0§out§8§0§

# %% [markdown]
# - To retrieve the wires connected to an instance, use `Module.get_edges`.
# - This returns a dictionary, where the keys are the names of the instance's ports, and the values are dictionaries with edge indices and their corresponding wire segments as values.
# - Execute the cell below to see which wires are connected to which ports of the adder instance.

# %%
edges = top_module.get_edges(adder_inst.name)
for port_name, edge_object in edges.items():
    print(f"The edges connected to port {port_name} are:")
    for edge_idx, edge_object in edge_object.items():
        print(f"\tEdge {edge_idx} is connected to wire segment {edge_object.raw_path}!")
# Out:
# The edges connected to port A are:
# 	Edge 0 is connected to wire segment simpleAdder.in1.0!
# 	Edge 1 is connected to wire segment simpleAdder.in1.1!
# 	Edge 2 is connected to wire segment simpleAdder.in1.2!
# 	Edge 3 is connected to wire segment simpleAdder.in1.3!
# 	Edge 4 is connected to wire segment simpleAdder.in1.4!
# 	Edge 5 is connected to wire segment simpleAdder.in1.5!
# 	Edge 6 is connected to wire segment simpleAdder.in1.6!
# 	Edge 7 is connected to wire segment simpleAdder.in1.7!
# The edges connected to port B are:
# 	Edge 0 is connected to wire segment simpleAdder.in2.0!
# 	Edge 1 is connected to wire segment simpleAdder.in2.1!
# 	Edge 2 is connected to wire segment simpleAdder.in2.2!
# 	Edge 3 is connected to wire segment simpleAdder.in2.3!
# 	Edge 4 is connected to wire segment simpleAdder.in2.4!
# 	Edge 5 is connected to wire segment simpleAdder.in2.5!
# 	Edge 6 is connected to wire segment simpleAdder.in2.6!
# 	Edge 7 is connected to wire segment simpleAdder.in2.7!
# The edges connected to port Y are:
# 	Edge 0 is connected to wire segment simpleAdder.§0§out§8§0§.0!
# 	Edge 1 is connected to wire segment simpleAdder.§0§out§8§0§.1!
# 	Edge 2 is connected to wire segment simpleAdder.§0§out§8§0§.2!
# 	Edge 3 is connected to wire segment simpleAdder.§0§out§8§0§.3!
# 	Edge 4 is connected to wire segment simpleAdder.§0§out§8§0§.4!
# 	Edge 5 is connected to wire segment simpleAdder.§0§out§8§0§.5!
# 	Edge 6 is connected to wire segment simpleAdder.§0§out§8§0§.6!
# 	Edge 7 is connected to wire segment simpleAdder.§0§out§8§0§.7!
# 	Edge 8 is connected to wire segment simpleAdder.§0§out§8§0§.8!

# %% [markdown]
# - The neighboring instances can also be accessed as objects via `Module.get_neighbors`, where the neighbors of the provided instance are returned.
# - This method returns a dictionary, where for each port of the instance, a number of neighboring ports is given.
# - The dictionary contains all instance or module ports that are directly connected to one of the instance's ports via a wire.
# - The neighboring port is either an instance port or a module port.
# - This means that a given neighbor is either an instance (if the neigboring port belongs to an instance) or a module port (if the neigboring port is a module port).
# - Execute the cell below to see the neighboring ports of the adder.

# %%
neighbors = top_module.get_neighbors(adder_inst.name)
for port_name, neighbor_dict in neighbors.items():
    print(f"Neighbors of port {port_name}:")
    for neighbor_idx, neighbor_list in neighbor_dict.items():
        print(f"\tIndex {neighbor_idx} is connected to port {', '.join(f'{p.raw_path}' for p in neighbor_list)}")
# Out:
# Neighbors of port A:
# 	Index 0 is connected to port simpleAdder.in1.0
# 	Index 1 is connected to port simpleAdder.in1.1
# 	Index 2 is connected to port simpleAdder.in1.2
# 	Index 3 is connected to port simpleAdder.in1.3
# 	Index 4 is connected to port simpleAdder.in1.4
# 	Index 5 is connected to port simpleAdder.in1.5
# 	Index 6 is connected to port simpleAdder.in1.6
# 	Index 7 is connected to port simpleAdder.in1.7
# Neighbors of port B:
# 	Index 0 is connected to port simpleAdder.in2.0
# 	Index 1 is connected to port simpleAdder.in2.1
# 	Index 2 is connected to port simpleAdder.in2.2
# 	Index 3 is connected to port simpleAdder.in2.3
# 	Index 4 is connected to port simpleAdder.in2.4
# 	Index 5 is connected to port simpleAdder.in2.5
# 	Index 6 is connected to port simpleAdder.in2.6
# 	Index 7 is connected to port simpleAdder.in2.7
# Neighbors of port Y:
# 	Index 0 is connected to port simpleAdder.§procdff§6.D.0
# 	Index 1 is connected to port simpleAdder.§procdff§6.D.1
# 	Index 2 is connected to port simpleAdder.§procdff§6.D.2
# 	Index 3 is connected to port simpleAdder.§procdff§6.D.3
# 	Index 4 is connected to port simpleAdder.§procdff§6.D.4
# 	Index 5 is connected to port simpleAdder.§procdff§6.D.5
# 	Index 6 is connected to port simpleAdder.§procdff§6.D.6
# 	Index 7 is connected to port simpleAdder.§procdff§6.D.7
# 	Index 8 is connected to port simpleAdder.§procdff§6.D.8

# %% [markdown]
# - To collect all preceeding instances (either module ports or instances), use the method `Module.get_preceeding_instances`.
# - Preceeding instances are instances that directly connect to one of the instance's input ports via wires, i.e. that drives a signal to an input port of this instance.
# - `Module.get_preceeding_instances` returns a dictionary, where the keys are the names of the instance's input ports (in this case **A** and **B**), and the values are again dictionaries, where the port index is the key, and the values are lists of instances that directly connect to this input port via wires.
# - Execute the cell below to see, which instances drive the signal on the input ports of the adder instance.
#
# <div class="admonition info alert alert-info">
#   <strong>Info:</strong> Unlike <i>Module.get_neighbors</i>, this method returns the <b>instance or port itself</b>, and not only the port segment of either the module port or instance port.
# </div>
# <div class="admonition warning alert alert-warning" style="color: darkred;">
#   <strong>Warning:</strong> Normally, each signal should be driven by only one driver.
#   The list of preceeding instances (i.e. signals drivers) should thus only contain one element.
#   Otherwise, there will be multiple driver conflicts.
#   This can be checked via <b>Wire.has_multiple_drivers</b>, which is explained further below.
# </div>

# %%
preceeding_instances = top_module.get_preceeding_instances(adder_inst.name)
for port_name, instance_dict in preceeding_instances.items():
    print(f"Port {port_name} is driven by instances:")
    for port_idx, inst_list in instance_dict.items():
        print(f"\t{inst_list}")
# Out:
# Port A is driven by instances:
# 	[Port(in1 at simpleAdder.in1)]
# 	[Port(in1 at simpleAdder.in1)]
# 	[Port(in1 at simpleAdder.in1)]
# 	[Port(in1 at simpleAdder.in1)]
# 	[Port(in1 at simpleAdder.in1)]
# 	[Port(in1 at simpleAdder.in1)]
# 	[Port(in1 at simpleAdder.in1)]
# 	[Port(in1 at simpleAdder.in1)]
# Port B is driven by instances:
# 	[Port(in2 at simpleAdder.in2)]
# 	[Port(in2 at simpleAdder.in2)]
# 	[Port(in2 at simpleAdder.in2)]
# 	[Port(in2 at simpleAdder.in2)]
# 	[Port(in2 at simpleAdder.in2)]
# 	[Port(in2 at simpleAdder.in2)]
# 	[Port(in2 at simpleAdder.in2)]
# 	[Port(in2 at simpleAdder.in2)]

# %% [markdown]
# - Similarly, the succeeding instances can be retrieved via `Module.get_succeeding_instances`.
# - Succeeding instances are instances that directly connect to one of the instance's output ports via wires, i.e. that receive a signal which is driven by an output port of this instance.
# - `Module.get_succeeding_instances` returns a dictionary, where the keys are the names of the instance's output ports (in this case **Y**), and the values are again dictionaries, where the port index is the key, and the values are lists of instances that directly connect to this output port via wires.
# - Execute the cell below to see, which instances receive the signals of the output port **Y** of the adder instance.

# %%
succeeding_instances = top_module.get_succeeding_instances(adder_inst.name)
for port_name, instance_dict in succeeding_instances.items():
    print(f"Port {port_name} drives signals to instances:")
    for port_idx, inst_list in instance_dict.items():
        print(f"\t{inst_list}")
# Out:
# Port Y drives signals to instances:
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]
# 	[ADFF(§adff: simpleAdder.§procdff§6)]

# %% [markdown]
# - Wires can either be retrieved via `Module.get_wire` (returns None if missing) or or `Module.wires[<wire_name>]` (raises error if missing).
# - Similar to ports, wires consist of segments, where an `n` bit wide wire consists of `n` segments.
# - Execute the cell below to see the properties of a wire exemplarily.

# %%
wire_in1 = top_module.get_wire("in1")
print(f"Wire {wire_in1.name} with path {wire_in1.raw_path} is {wire_in1.width} bit wide.")
print(f"Wire {wire_in1.name} is connected to the following ports:")
for seg_idx, segment in wire_in1:
    print(f"\tSegment {seg_idx} is connected to port segments: {', '.join(p.raw_path for p in segment.port_segments)}")
# Out:
# Wire in1 with path simpleAdder.in1 is 8 bit wide.
# Wire in1 is connected to the following ports:
# 	Segment 0 is connected to port segments: simpleAdder.in1.0, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.0, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.0
# 	Segment 1 is connected to port segments: simpleAdder.in1.1, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.1, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.1
# 	Segment 2 is connected to port segments: simpleAdder.in1.2, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.2, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.2
# 	Segment 3 is connected to port segments: simpleAdder.in1.3, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.3, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.3
# 	Segment 4 is connected to port segments: simpleAdder.in1.4, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.4, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.4
# 	Segment 5 is connected to port segments: simpleAdder.in1.5, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.5, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.5
# 	Segment 6 is connected to port segments: simpleAdder.in1.6, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.6, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.6
# 	Segment 7 is connected to port segments: simpleAdder.in1.7, simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.7, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.7

# %% [markdown]
# ## Analyze wire connectivity
# - The circuit's topology can be explored, especially in regards to wire connectivity.
# - In the cell below, this is shown exemplarily for the wire `in1` along with methods to check for possible issues regarding this wire.
# - These methods can be used to check any wire for issues.

# %%
print(f"Checking wire {wire_in1.name} for possible issues...")
if wire_in1.has_no_driver():
    print(f"\tWire {wire_in1.name} has no driver.")
else:
    print(f"\tWire {wire_in1.name} does have a driver.")

if wire_in1.has_multiple_drivers():
    print(f"\tWire {wire_in1.name} has multiple drivers.")
else:
    print(f"\tWire {wire_in1.name} does not have multiple drivers.")

if wire_in1.has_no_loads():
    print(f"\tWire {wire_in1.name} has no loads.")
else:
    print(f"\tWire {wire_in1.name} has loads.")

if wire_in1.is_dangling():
    print(f"\tWire {wire_in1.name} is dangling (either no driver or no load).")
else:
    print(f"\tWire {wire_in1.name} is not dangling (driver and load exist).")

if wire_in1.has_problems():
    print(f"\tWire {wire_in1.name} has issues (e.g. multiple drivers, no driver or no loads).")
else:
    print(f"\tWire {wire_in1.name} does not have any issues.")
# Out:
# Checking wire in1 for possible issues...
# 	Wire in1 does have a driver.
# 	Wire in1 does not have multiple drivers.
# 	Wire in1 has loads.
# 	Wire in1 is not dangling (driver and load exist).
# 	Wire in1 does not have any issues.

# %% [markdown]
# - The methods presented in the cell above may also take a parameter `get_mapping` (bool), which defaults to `False`.
# - If set to `True`, they return a dictionary with the indices of the wire and the corresponding boolean value for the method call.
# - Execute the cell below to see how the method `Wire.has_multiple_drivers` behaves for the wire `in1` when `get_mapping` is `True`.

# %%
has_multiple_drivers_mapping = wire_in1.has_multiple_drivers(get_mapping=True)
print(f"Wire.has_multiple_drivers returns the following mapping for {wire_in1.name}:")
for idx, has_multiple_drivers in has_multiple_drivers_mapping.items():
    print(f"\t{idx} -> {has_multiple_drivers}")
print("'False' means that this wire segment does not have multiple drivers, 'True' means it does.")
# Out:
# Wire.has_multiple_drivers returns the following mapping for in1:
# 	0 -> False
# 	1 -> False
# 	2 -> False
# 	3 -> False
# 	4 -> False
# 	5 -> False
# 	6 -> False
# 	7 -> False
# 'False' means that this wire segment does not have multiple drivers, 'True' means it does.

# %% [markdown]
# - The signal driving and signal load ports can be retrieved for each segment of the wire via `Wire.driver` and `Wire.load`.
# - Execute the cell below to see the driver and load instances for each segment of the wire `wire_in1`.

# %%
drivers = wire_in1.driver()
print(f"Drivers of wire {wire_in1.name}:")
for idx, driver in drivers.items():
    print(f"\tSegment {idx} is driven by the following port segment: {driver}")

loads = wire_in1.loads()
print(f"Loads of wire {wire_in1.name}:")
for idx, load_list in loads.items():
    print(f"\tSegment {idx} drives the following port segments: {', '.join(d.raw_path for d in load_list)}")
# Out:
# Drivers of wire in1:
# 	Segment 0 is driven by the following port segment: PortSegment "0" with path simpleAdder.in1.0
# 	Segment 1 is driven by the following port segment: PortSegment "1" with path simpleAdder.in1.1
# 	Segment 2 is driven by the following port segment: PortSegment "2" with path simpleAdder.in1.2
# 	Segment 3 is driven by the following port segment: PortSegment "3" with path simpleAdder.in1.3
# 	Segment 4 is driven by the following port segment: PortSegment "4" with path simpleAdder.in1.4
# 	Segment 5 is driven by the following port segment: PortSegment "5" with path simpleAdder.in1.5
# 	Segment 6 is driven by the following port segment: PortSegment "6" with path simpleAdder.in1.6
# 	Segment 7 is driven by the following port segment: PortSegment "7" with path simpleAdder.in1.7
# Loads of wire in1:
# 	Segment 0 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.0, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.0
# 	Segment 1 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.1, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.1
# 	Segment 2 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.2, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.2
# 	Segment 3 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.3, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.3
# 	Segment 4 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.4, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.4
# 	Segment 5 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.5, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.5
# 	Segment 6 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.6, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.6
# 	Segment 7 drives the following port segments: simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.7, simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.7

# %% [markdown]
# - Similarly, the object to which the port segment belongs to (either an instance or a module port) can be retrieved via `Module.get_connected_ports`.
# - Especially `Module.get_driving_ports` and `Module.get_load_ports` return the driving and load objects, respectively.
# - All three mentioned methods return a set of PortSegment objects.
#     - `Module.get_connected_ports`: all port segments connected to the given wire segment.
#     - `Module.get_driving_ports`: only the drivers (which should only be one).
#     - `Module.get_load_ports`: only the load port segments.
# - Execute the cell below to see the port segments sets for the different use cases.

# %%
driving_nodes = top_module.get_driving_ports(wire_in1[0].path)
for port_segment in driving_nodes:
    if port_segment.parent.is_module_port:
        print(f"Wire {wire_in1.name} is driven by port segment {port_segment.raw_path}, which belongs to a module port.")
    else:
        print(f"Wire {wire_in1.name} is driven by port segment {port_segment.raw_path}, which belongs to an instance port.")
    print(f"\tRaw data: {port_segment}")

load_nodes = top_module.get_load_ports(wire_in1[0].path)
for port_segment in load_nodes:
    if port_segment.parent.is_module_port:
        print(f"Wire {wire_in1.name} drives port segment {port_segment.raw_path}, which belongs to a module port.")
    else:
        print(f"Wire {wire_in1.name} drives port segment {port_segment.raw_path}, which belongs to an instance port.")
    print(f"\tRaw data: {port_segment}")
# Out:
# Wire in1 is driven by port segment simpleAdder.in1.0, which belongs to a module port.
# 	Raw data: PortSegment "0" with path simpleAdder.in1.0
# Wire in1 drives port segment simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.0, which belongs to an instance port.
# 	Raw data: PortSegment "0" with path simpleAdder.§add§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§26§2.A.0
# Wire in1 drives port segment simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.0, which belongs to an instance port.
# 	Raw data: PortSegment "0" with path simpleAdder.§or§/wrk/mik/mjirsak/NetlistCarpentry/netlist-carpentry/docs/src/user_guide/files/simpleAdder§v§27§3.A.0

# %% [markdown]
# ## Selecting slices (segments) of a port or wire
# - Often, ports or wires are wider than 1 bit.
# - Each segment of the port or wire is represented by a single-bit slice of the port or wire.
# - Segments can be accessed either directly via their dictionary `Port.segments[idx]` and `Wire.segments[idx]`, or via a shortcut `Port[idx]` and `Wire[idx]`.
# - The dictionaries follow the format {idx: segment}.
# - In the cell below, this is shown exemplarily for the 9-bit wide output port `out`, which thus consists of 9 segments.

# %%
out_port = top_module.ports["out"]

print(f"Port '{out_port.name}' has the following segments:")
for idx, segment in out_port:
    print(f"\tIndex {idx}: {segment}")

print(f"This is the segment at index 0: {out_port.segments[0]}")
print(f"This is also the segment at index 0: {out_port[0]}")
# Out:
# Port 'out' has the following segments:
# 	Index 0: PortSegment "0" with path simpleAdder.out.0
# 	Index 1: PortSegment "1" with path simpleAdder.out.1
# 	Index 2: PortSegment "2" with path simpleAdder.out.2
# 	Index 3: PortSegment "3" with path simpleAdder.out.3
# 	Index 4: PortSegment "4" with path simpleAdder.out.4
# 	Index 5: PortSegment "5" with path simpleAdder.out.5
# 	Index 6: PortSegment "6" with path simpleAdder.out.6
# 	Index 7: PortSegment "7" with path simpleAdder.out.7
# 	Index 8: PortSegment "8" with path simpleAdder.out.8
# This is the segment at index 0: PortSegment "0" with path simpleAdder.out.0
# This is also the segment at index 0: PortSegment "0" with path simpleAdder.out.0

# %% [markdown]
# ## Selecting Elements based on their path
# - Circuit elements can be accessed via their path.
# - An `ElementPath` object consists of the path string itself and the type of the element, which is used for faster look-up.
# - The path string is a dot-separated string used to identify elements in the circuit.
# - For example, the path string `simpleAdder.in1` identifies the input port `in1` of the module `simpleAdder`, and the type of the path is required to look in the correct dictionary, and for certain additional operations.
# - The part `simpleAdder` of the path string identifies the module, and any following part is therefore located inside this module.
# - The path string `in1` identifies an object inside the module (which here is the input port `in1`).
# - With `Module.get_from_path`, elements from inside the module can be retrieved by using its path.
# - Execute the cell below to retrieve the input port `in1` of the module `simpleAdder` by using its path.

# %%
from netlist_carpentry.core.netlist_elements.element_path import PortPath, PortSegmentPath

path_in1 = PortPath(raw="simpleAdder.in1")

port_in1 = top_module.get_from_path(path_in1)
print(f"Port {port_in1.name} has the path '{port_in1.raw_path}', which forms this ElementPath object: {port_in1.path}")
# Out:
# Port in1 has the path 'simpleAdder.in1', which forms this ElementPath object: PortPath(simpleAdder.in1)

# %% [markdown]
# - In the same way, elements further down in the hierarchy can be retrieved as well.
# - To select a segment of the port `in1`, it can be included into the element path.
# - In this concrete case, to retrieve the segment `0` of the port `in1`, the full element path is `simpleAdder.in1.0`.
# - Execute the cell below to retrieve the port segment `0` of the module `simpleAdder` by using its path and `Module.get_from_path`.

# %%
path_in1_0 = PortSegmentPath(raw="simpleAdder.in1.0")

port_in1_0 = top_module.get_from_path(path_in1_0)
print(f"Port Segment {port_in1_0.name} has the path '{port_in1_0.raw_path}', which forms this ElementPath object: {port_in1_0.path}")
# Out:
# Port Segment 0 has the path 'simpleAdder.in1.0', which forms this ElementPath object: PortSegmentPath(simpleAdder.in1.0)

# %% [markdown]
# - Alternatively, the paths can be retrieved directly via the `Circuit` object in the same way using `Circuit.get_from_path`.
# - Execute the cell below to retrieve a Port Segment similar to the cell above, but now using the `Circuit.get_from_path` method.
#
# <div class="admonition info alert alert-info">
#   <strong>Info:</strong> This also works for paths with multiple nested hierarchies, e.g. <b>module.inst1.inst2.inst3.some_port</b>.
#   Unlike the previously presented method <b>Module.get_from_path</b>, the method <b>Circuit.get_from_path</b> includes all modules of the circuit for possible submodule instantiations.
#   This way, paths across several hierarchy levels are also evaluated correctly.
# </div>

# %%
path_in1_1 = PortSegmentPath(raw="simpleAdder.in1.1")

port_in1_1 = circuit.get_from_path(path_in1_1)
print(f"Port Segment {port_in1_1.name} has the path '{port_in1_1.raw_path}', which forms this ElementPath object: {port_in1_1.path}")
# Out:
# Port Segment 1 has the path 'simpleAdder.in1.1', which forms this ElementPath object: PortSegmentPath(simpleAdder.in1.1)
